# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv('/users/richardkornblith/Data_Science/NYCHR/Data_for_NYCHR/ACS_15_5YR_by_tract/ACS_15_5YR_B25063_with_ann.csv')
df.head()
# Out:
#                  GEO.id      GEO.id2  \
# 0                    Id          Id2
# 1  1400000US36061000100  36061000100
# 2  1400000US36061000201  36061000201
# 3  1400000US36061000202  36061000202
# 4  1400000US36061000500  36061000500
#
#                               GEO.display-label         HD01_VD01  \
# 0                                     Geography  Estimate; Total:
# 1     Census Tract 1, New York County, New York                 0
# 2  Census Tract 2.01, New York County, New York               972
# 3  Census Tract 2.02, New York County, New York              2649
# 4     Census Tract 5, New York County, New York                 0
#
#                  HD02_VD01                  HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; With cash rent:
# 1                       11                          0
# 2                       71                        972
# 3                      197                       2649
# 4                       11                          0
#
# ...

# %%
df.drop([0], inplace=True)

# %%
df.rename(columns={'HD01_VD02':'Units','HD01_VD23':'2000-2499','HD01_VD24':'2500-2999','HD01_VD25':'3000-3499','HD01_VD26':'3500 or more'}, inplace=True)
df.shape
# Out:
# (288, 57)

# %%
rents2015_df = df[['Units', '2000-2499', '2500-2999','3000-3499','3500 or more']]
rents2015_df = rents_df.astype(int)
rents2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 1 to 288
# Data columns (total 5 columns):
# Units           288 non-null int64
# 2000-2499       288 non-null int64
# 2500-2999       288 non-null int64
# 3000-3499       288 non-null int64
# 3500 or more    288 non-null int64
# dtypes: int64(5)
# memory usage: 13.5 KB

# %%
rents2015_df.head()
# Out:
#    Units  2000-2499  2500-2999  3000-3499  3500 or more
# 1      0          0          0          0             0
# 2    972         64         11          0             0
# 3   2649          0         15         11             0
# 4      0          0          0          0             0
# 5   4069         59         31         31            67

# %%
rents2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 1 to 288
# Data columns (total 5 columns):
# Units           288 non-null int64
# 2000-2499       288 non-null int64
# 2500-2999       288 non-null int64
# 3000-3499       288 non-null int64
# 3500 or more    288 non-null int64
# dtypes: int64(5)
# memory usage: 13.5 KB
